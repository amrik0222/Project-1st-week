# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set_style('darkgrid')

import pandas as pd
con=mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password="London01",
    database="testdb")
df=pd.read_sql_query("select * from student_marks",con)
df
df.head(10)
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  1988-04-05     55       45         56       87       21
# 1    Suresh      M  1987-05-04     75       96         78       64       90
# 2    Ramesh      M  1989-05-25     25       54         89       76       95
# 3   Jessica      F  1990-08-12     78       96         86       63       54
# 4  Jennifer      F  1989-09-02     58       96         78       46       96
# 5      Annu      F  1988-04-05     45       87         52       89       55
# 6     Pooja      F  1987-05-04     55       64         61       58       75
# 7    Ritesh      M  1989-05-25     54       76         87       56       25
# 8     Farha      F  1990-08-12     55       63         89       75       78
# 9    Mukesh      M  1989-09-02     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
df['Total Score']=df['Maths']+df['Physics']+df['Chemistry']+df['English']+df['Biology']+df['Economics']+df['History']+df['Civics']

# %%
df.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  1988-04-05     55       45         56       87       21
# 1    Suresh      M  1987-05-04     75       96         78       64       90
# 2    Ramesh      M  1989-05-25     25       54         89       76       95
# 3   Jessica      F  1990-08-12     78       96         86       63       54
# 4  Jennifer      F  1989-09-02     58       96         78       46       96
#
#    Economics  History  Civics  Total Score
# 0         52       89      65          470
# 1         61       58       2          524
# 2         87       56      74          556
# 3         89       75      45          586
# 4         77       83      53          587

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
# Name           10 non-null object
# Gender         10 non-null object
# DOB            10 non-null object
# Maths          10 non-null int64
# Physics        10 non-null int64
# Chemistry      10 non-null int64
# English        10 non-null int64
# Biology        10 non-null int64
# Economics      10 non-null int64
# History        10 non-null int64
# Civics         10 non-null int64
# Total Score    10 non-null int64
# dtypes: int64(9), object(3)
# memory usage: 1.1+ KB

# %%
sns.pairplot(data=df,hue='Gender')

# %%
df.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  1988-04-05     55       45         56       87       21
# 1    Suresh      M  1987-05-04     75       96         78       64       90
# 2    Ramesh      M  1989-05-25     25       54         89       76       95
# 3   Jessica      F  1990-08-12     78       96         86       63       54
# 4  Jennifer      F  1989-09-02     58       96         78       46       96
#
#    Economics  History  Civics  Total Score
# 0         52       89      65          470
# 1         61       58       2          524
# 2         87       56      74          556
# 3         89       75      45          586
# 4         77       83      53          587

# %%
toppers = df.sort_values(by=['Total Score'],ascending=False)

# %%
toppers.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 4  Jennifer      F  1989-09-02     58       96         78       46       96
# 8     Farha      F  1990-08-12     55       63         89       75       78
# 3   Jessica      F  1990-08-12     78       96         86       63       54
# 9    Mukesh      M  1989-09-02     96       46         77       83       58
# 2    Ramesh      M  1989-05-25     25       54         89       76       95
#
#    Economics  History  Civics  Total Score
# 4         77       83      53          587
# 8         75       63      89          587
# 3         89       75      45          586
# 9         83       46      77          566
# 2         87       56      74          556

# %%
toppers
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 4  Jennifer      F  1989-09-02     58       96         78       46       96
# 8     Farha      F  1990-08-12     55       63         89       75       78
# 3   Jessica      F  1990-08-12     78       96         86       63       54
# 9    Mukesh      M  1989-09-02     96       46         77       83       58
# 2    Ramesh      M  1989-05-25     25       54         89       76       95
# 5      Annu      F  1988-04-05     45       87         52       89       55
# 1    Suresh      M  1987-05-04     75       96         78       64       90
# 7    Ritesh      M  1989-05-25     54       76         87       56       25
# 6     Pooja      F  1987-05-04     55       64         61       58       75
# 0      John      M  1988-04-05     55       45         56       87       21
#
#    Economics  History  Civics  Total Score
# 4         77       83      53          587
# 8         75       63      89          587
# ...

# %%
df.shape
# Out:
# (10, 12)

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civics', 'Total Score'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics  Total Score
# count  10.000000  10.0000     10.00000
# mean   69.700000  60.5000    544.50000
# std    14.453373  25.3432     41.01558
# min    46.000000   2.0000    470.00000
# 25%    59.250000  52.2500    518.75000
# 50%    69.500000  63.0000    556.00000
# 75%    81.250000  76.2500    581.00000
# ...

# %%
df.isnull().sum()
# Out:
# Name           0
# Gender         0
# DOB            0
# Maths          0
# Physics        0
# Chemistry      0
# English        0
# Biology        0
# Economics      0
# History        0
# Civics         0
# Total Score    0
# dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression

sns.heatmap(df.isnull())

# %%
sns.pairplot(df)
